# %%
import os
import base64
import datetime
from google.auth.transport.requests import Request
from google.oauth2.credentials import Credentials
from google_auth_oauthlib.flow import InstalledAppFlow
from googleapiclient.discovery import build
import PyPDF2

# If modifying these SCOPES, delete the file token.json.
SCOPES = ['https://www.googleapis.com/auth/gmail.readonly']

# Directory to save attachments
attachment_dir = "attachments\\"

# Whitelist text file (domains only)
whitelist_file = "whitelist.txt"

# Words to search for in the PDFs
search_words = [ "facture", "invoice"]

def load_whitelist():
    if os.path.exists(whitelist_file):
        with open(whitelist_file, 'r') as file:
            return [line.strip() for line in file.readlines()]
    return []

def authenticate_gmail():
    creds = None
    if os.path.exists('token.json'):
        creds = Credentials.from_authorized_user_file('token.json', SCOPES)
    if not creds or not creds.valid:
        if creds and creds.expired and creds.refresh_token:
            creds.refresh(Request())
        else:
            flow = InstalledAppFlow.from_client_secrets_file(
                'credentials.json', SCOPES)
            creds = flow.run_local_server(port=0)
        with open('token.json', 'w') as token:
            token.write(creds.to_json())
    return creds

def fetch_emails(service, whitelist):
    results = service.users().messages().list(userId='me').execute()
    messages = results.get('messages', [])
    
    for message in messages:
        msg = service.users().messages().get(userId='me', id=message['id']).execute()
        headers = msg.get('payload', {}).get('headers', [])
        from_email = None
        for header in headers:
            if header['name'] == 'From':
                from_email = header['value']
                break
        domain = from_email.split('@')[-1][:-1]
        if from_email and any(whitelisted_domain in domain for whitelisted_domain in whitelist):
            print(f"Email from {from_email}:")
            print("Subject:", get_header(headers, 'Subject'))
            print("Body:", get_body(msg))
            download_attachments(service, msg, domain)

def get_header(headers, name):
    for header in headers:
        if header['name'] == name:
            return header['value']
    return None

def get_body(msg):
    parts = msg.get('payload', {}).get('parts', [])
    for part in parts:
        if part.get('mimeType') == 'text/plain':
            body = part['body'].get('data')
            if body:
                return base64.urlsafe_b64decode(body).decode('utf-8')
    return None

def download_attachments(service, msg, domain):
    parts = msg.get('payload', {}).get('parts', [])
    for part in parts:
        if 'filename' in part and part['filename'].endswith('.pdf'):
            att_id = part['body'].get('attachmentId')
            attachment = service.users().messages().attachments().get(
                userId='me', messageId=msg['id'], id=att_id).execute()
            data = base64.urlsafe_b64decode(attachment['data'])
            save_attachment(part['filename'], data, domain)

def save_attachment(filename, data, domain):
    # Create the domain directory with matching and non_matching subdirectories
    domain_dir = os.path.join(attachment_dir, domain)
    matching_dir = os.path.join(domain_dir, "factures")
    non_matching_dir = os.path.join(domain_dir, "autres")
    
    for dir_path in [matching_dir, non_matching_dir]:
        if not os.path.exists(dir_path):
            os.makedirs(dir_path)

    # Add domain and date to the filename
    date_str = datetime.datetime.now().strftime("%Y%m%d")
    new_filename = f"{domain}{date_str}_{os.path.splitext(filename)[0]}_.pdf"
    
    # Temporarily save the file to the domain directory for word check
    temp_filepath = os.path.join(domain_dir, new_filename)
    with open(temp_filepath, 'wb') as f:
        f.write(data)
    
    # Check if any of the words are in the PDF
    if is_word_in_pdf(temp_filepath, search_words):
        final_filepath = os.path.join(matching_dir, new_filename)
    else:
        final_filepath = os.path.join(non_matching_dir, new_filename)
    
    # Move the file to the appropriate folder
    os.rename(temp_filepath, final_filepath)
    print(f"Saved attachment to {final_filepath}")

def is_word_in_pdf(pdf_path, words):
    with open(pdf_path, 'rb') as file:
        reader = PyPDF2.PdfReader(file)
        for page_num in range(len(reader.pages)):
            page = reader.pages[page_num]
            text = page.extract_text()
            for word in words:
                if word.lower() in text.lower():
                    return True
    return False

def main():
    whitelist = load_whitelist()
    creds = authenticate_gmail()
    service = build('gmail', 'v1', credentials=creds)
    fetch_emails(service, whitelist)


#if __name__ == '__main__':
main()
# Out:
# Email from Jennifer Longo <jenniferlo@aca.ca>:
# Subject: RE: ETAT DE COMPTE
# Body: None
# Email from Jennifer Longo <jenniferlo@aca.ca>:
# Subject: RE: ETAT DE COMPTE
# Body: None
# Email from "Kumar, MBharath" <Bharath.Mora@dell.com>:
# Subject: RE: Dell - Statement - POLYRIX INC. - CA8496521
# Body: None
# Email from Alexandre Legault <alegault@capitalwinch.com>:
# Subject: Re: Facture - Rappel : Votre paiement à Capital Winch Inc. est dû
# Body: En effet j'ai bien reçu.
#
# Merci du retour rapide
#
# Bonne journée,
#
#
# Alexandre Legault, ing. P. Eng.
#
# Capital Winch
#
# 435 rue Bérubé
#
# Québec, QC G1M 1C7
#
# Tél.: 418-628-2142
#
# Cell.: 418-473-5375
#
# Courriel : alegault@capitalwinch.com <alegault@caipitalwinch.com>
#
# Web : www.capitalwinch.com
#
#
# On Mon, Aug 19, 2024 at 3:46 PM Comptabilite Polyrix <
# comptabilite@polyrix.com> wrote:
#
# >
# >
# > Bonjour
# >
# > Je vous envoie ici la preuve de paiement fait au 2 aout dernier
# > en espérant qu'il y ait aucune confusion.
# >
# > merci
# >
# > Isabel Moreau
# > comptabilité pour Polyrix
# >
# >
# >
# > Le lun. 19 août 2024, à 14 h 35, Capital Winch Inc. <
# > quickbooks@notification.intuit.com> a écrit :
# >
# >>
# >>
# >> Nº DE FACTURE 781
# >> Capital Winch Inc.
# >>
# >>
# >> ÉCHÉANCE 08-08-2024
# >> 1 523,42 CAD
# >> Imprimer ou enregistrer
# >> <http://links.notification.intuit.com/ls/click?upn=u001.Hu9nToJLxsJSQR8ZHWn8Ib7JikYF6PNXv5VK-2BAfeSpVHPRNy-2BFDtJ-2BhNUfKXTverofrKjvXVKH4ba5KbTX-2BS4cvo221OK-2FoRt6yS-2FQV0Xqe6lNgL92z-2BC45dXyb-2FtKo-2FcK7TtZS1urIatQ0N73-2FWvFARkv4GfNyhdtPcv-2FxY3jOjwLSZDBpfr-2Fuo11h6NQLCVZSicWVfuRUykANIejRzm-2FuK-2FNfyjq4JVJz2v6hzkFppBcX4WNpgrJxWFlK090jYZ-2FOUcUoJ2V5IWBaTMlVOhCoS0ve-2BxanT32aQBCGPalw-3DJLBl_ehzziKtP7hMfiu7UN3KHq0Sh31PR42wtzGgWWCMu9lDwV9lL0p3jh0r0veLWBFyYm6QQv08c-2BH1BbeXMHoykKvvts7JmKAHzDnX8iMaIFoBTgTYQtg3DG8TGLKGFPXb0nT-2BhjEnpGxVYiZqkI2Lf9tSa1LNegYERu4RSNTByjt-2Fc7YvYJuY4Gj
2FcrkZGpCbDgYcgWCVxryOtv6x9YMaVgwrKVelxJyl0KLusvxFf6Xq867gRinqOUPMn1QofvCVP5pdBAT2Ie85PTLh8T5Z92knuhg0aHCf7Afjkv9SIgt8FzSKRLQ7sw9DgGC3ICG5DbAvMlmJbliLjhLel08LUvwg6B-2FCzxhkaQ1fFWQfr9QIQHEFWQcN87aT-2BJgvhyPwsCy-2FcRtl-2FVq-2BpG6d8kbaYbUGn6akx4OMGGNGHV4-2BIvqR316V1iNFO20P9ZQ-2BPyVlDOHvffwjNUkzIqi5S88t4LTGhskTobEr5nkfWugHHjbGvgktGd-2FQNkBFtiPUWdDWckUdLL87JxSjD-2BEQ6q9n2g6IoM3F0J7LZsyUWvnsNjSLfTdKLYuv3zk799yBs4JUIfW3OATsfF-2F5hyQGjzbkp0PU9pF3snSHmKUyLOrJKHLDF7zpkDO4PR4vBCVERpyI3oQI3V31Sz-2BphpoXkhZ70zWkPPWJ5lBKgdp3kCTUyVR7BD8Bc9M34McIfxS4WuLZw9dxkmh0d8iqMxpcO62yNghCrlVB9-2FvQ7bXHWxabZow3r5tOmnmxhLMRJofr12njUBaYt0cpj5BmTuv6azxDZah3hp-2FXuM9YBOeOFmFlhHNR6c9JCSv6Ouc-2Fh5yhwa3UDa4NOrn6xo9dcmf8IAYPboMyrAGl5Uhg9YpRMjxuObaGF6nUSPur-2BAyukuVj7xGN4C-2BB5iKqS5zOO1Ws75>
# >>
# >>
# >
#
# Email from Jennifer Longo <jenniferlo@aca.ca>:
# Subject: RE: ETAT DE COMPTE
# Body: None
# Saved attachment to attachments\aca.ca\factures\aca.ca20240821_Sales Invoice SI110499_.pdf
# Saved attachment to attachments\aca.ca\factures\aca.ca20240821_Statement - Polyrix Inc._.pdf
# Email from Jennifer Longo <jenniferlo@aca.ca>:
# Subject: ETAT DE COMPTE
# Body: None
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# Cell In[7], line 135
#     131     fetch_emails(service, whitelist)
#     134 #if __name__ == '__main__':
# --> 135 main()
#
# Cell In[7], line 131, in main()
#     129 creds = authenticate_gmail()
#     130 service = build('gmail', 'v1', credentials=creds)
# --> 131 fetch_emails(service, whitelist)
#
# Cell In[7], line 60, in fetch_emails(service, whitelist)
#      58 print("Subject:", get_header(headers, 'Subject'))
#      59 print("Body:", get_body(msg))
# ---> 60 download_attachments(service, msg, domain)
#
# Cell In[7], line 85, in download_attachments(service, msg, domain)
#      82 attachment = service.users().messages().attachments().get(
#      83     userId='me', messageId=msg['id'], id=att_id).execute()
#      84 data = base64.urlsafe_b64decode(attachment['data'])
# ---> 85 save_attachment(part['filename'], data, domain)
#
# Cell In[7], line 113, in save_attachment(filename, data, domain)
#     110     final_filepath = os.path.join(non_matching_dir, new_filename)
#     112 # Move the file to the appropriate folder
# --> 113 os.rename(temp_filepath, final_filepath)
#     114 print(f"Saved attachment to {final_filepath}")
#
# FileExistsError: [WinError 183] Impossible de créer un fichier déjà existant: 'attachments\\aca.ca\\aca.ca20240821_Statement - Polyrix Inc._.pdf' -> 'attachments\\aca.ca\\factures\\aca.ca20240821_Statement - Polyrix Inc._.pdf'
