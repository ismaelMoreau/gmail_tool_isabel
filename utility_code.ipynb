# %%
import os
import base64
import datetime
from google.auth.transport.requests import Request
from google.oauth2.credentials import Credentials
from google_auth_oauthlib.flow import InstalledAppFlow
from googleapiclient.discovery import build
import PyPDF2
import logging

# Set up logging
logging.basicConfig(filename="attachment_errors.log", level=logging.ERROR, format="%(asctime)s - %(levelname)s - %(message)s")

# If modifying these SCOPES, delete the file token.json.
SCOPES = ['https://www.googleapis.com/auth/gmail.modify']

# Directory to save attachments
attachment_dir = "C:\\Users\\Isabe\\OneDrive\\Bureau\\factures\\exercise_en_cours"

# Whitelist text file (domains only)
whitelist_file = "whitelist.txt"

# Words to search for in the PDFs
search_words = ["facture", "invoice"]

def load_whitelist():
    if os.path.exists(whitelist_file):
        with open(whitelist_file, 'r') as file:
            return [line.strip() for line in file.readlines()]
    return []

def authenticate_gmail():
    creds = None
    if os.path.exists('token.json'):
        creds = Credentials.from_authorized_user_file('token.json', SCOPES)
    if not creds or not creds.valid:
        if creds and creds.expired and creds.refresh_token:
            creds.refresh(Request())
        else:
            flow = InstalledAppFlow.from_client_secrets_file('credentials.json', SCOPES)
            creds = flow.run_local_server(port=0)
        with open('token.json', 'w') as token:
            token.write(creds.to_json())
    return creds

def fetch_emails(service, whitelist):
    page_token = None
    while True:
        try:
            results = service.users().messages().list(
                userId='me',
                labelIds=['INBOX'],
                pageToken=page_token
            ).execute()
            
            messages = results.get('messages', [])
            print(f"Found {len(messages)} messages in the inbox.")
            
            for message in messages:
                print(f"Processing message ID: {message['id']}")
                msg = service.users().messages().get(userId='me', id=message['id']).execute()
                
                headers = msg.get('payload', {}).get('headers', [])
                from_email = None
                for header in headers:
                    if header['name'] == 'From':
                        from_email = header['value']
                        break
                domain = from_email.split('@')[-1][:-1]
                if from_email and any(whitelisted_domain in domain for whitelisted_domain in whitelist):
                    print(f"Email from {from_email}:")
                    print("Subject:", get_header(headers, 'Subject'))
                    
                    if process_attachments(service, msg, domain):
                        archive_email(service, message['id'], domain)
                    
            page_token = results.get('nextPageToken')
            if not page_token:
                break
        except Exception as e:
            print(f"Error fetching emails: {e}")
            break

def get_header(headers, name):
    for header in headers:
        if header['name'] == name:
            return header['value']
    return None

def process_attachments(service, msg, domain):
    try:
        found_valid_attachment = False
        
        # Ensure the temp directory exists
        temp_dir = "C:\\Users\\Isabe\\OneDrive\\Bureau\\attachments\\temp"
        if not os.path.exists(temp_dir):
            os.makedirs(temp_dir)
        
        parts = msg.get('payload', {}).get('parts', [])
        for part in parts:
            if 'filename' in part and part['filename'].endswith('.pdf'):
                att_id = part['body'].get('attachmentId')
                attachment = service.users().messages().attachments().get(
                    userId='me', messageId=msg['id'], id=att_id).execute()
                data = base64.urlsafe_b64decode(attachment['data'])
                
                # Create a temporary file to check if it contains the desired words
                temp_filepath = os.path.join(temp_dir, part['filename'])
                with open(temp_filepath, 'wb') as f:
                    f.write(data)
                
                if is_word_in_pdf(temp_filepath, search_words):
                    save_attachment(part['filename'], data, domain)
                    found_valid_attachment = True
                
                # Clean up the temporary file
                os.remove(temp_filepath)
    except Exception as e:
            print(f"Error fetching emails: {e}")
            
    return found_valid_attachment

def save_attachment(filename, data, domain):
    try:
        domain_dir = os.path.join(attachment_dir, domain)
        matching_dir = os.path.join(domain_dir, "factures")
        non_matching_dir = os.path.join(domain_dir, "autres")

        for dir_path in [matching_dir, non_matching_dir]:
            if not os.path.exists(dir_path):
                os.makedirs(dir_path)

        date_str = datetime.datetime.now().strftime("%Y%m%d")
        new_filename = f"{domain}{date_str}_{os.path.splitext(filename)[0]}_.pdf"

        temp_filepath = os.path.join(domain_dir, new_filename)
        with open(temp_filepath, 'wb') as f:
            f.write(data)

        if is_word_in_pdf(temp_filepath, search_words):
            final_filepath = os.path.join(matching_dir, new_filename)
        else:
            final_filepath = os.path.join(non_matching_dir, new_filename)

        os.rename(temp_filepath, final_filepath)
        print(f"Saved attachment to {final_filepath}")

    except FileExistsError as e:
        print(f"FileExistsError: {e} - {new_filename}")
    except Exception as e:
        print(f"Error: {e} - {new_filename}")

def is_word_in_pdf(pdf_path, words):
    with open(pdf_path, 'rb') as file:
        reader = PyPDF2.PdfReader(file)
        for page_num in range(len(reader.pages)):
            page = reader.pages[page_num]
            text = page.extract_text()
            for word in words:
                if word.lower() in text.lower():
                    return True
    return False

def archive_email(service, message_id, domain):
    try:
        label_name = f"En traitement factures"
        
        labels = service.users().labels().list(userId='me').execute().get('labels', [])
        label_id = None
        for label in labels:
            if label['name'] == label_name:
                label_id = label['id']
                break
        
        if not label_id:
            label = service.users().labels().create(
                userId='me',
                body={'name': label_name, 'labelListVisibility': 'labelShow', 'messageListVisibility': 'show'}
            ).execute()
            label_id = label['id']
        
        service.users().messages().modify(
            userId='me', id=message_id, body={
                'addLabelIds': [label_id],
                'removeLabelIds': ['INBOX']
            }
        ).execute()
        print(f"Email {message_id} archived under {label_name}.")
    except Exception as e:
        print(f"Error archiving email {message_id} under {label_name}: {e}")

def main():
    whitelist = load_whitelist()
    creds = authenticate_gmail()
    service = build('gmail', 'v1', credentials=creds)
    fetch_emails(service, whitelist)

#if __name__ == '__main__':
main()
# Out:
# Found 100 messages in the inbox.
# Processing message ID: 191be52b62068edb
# Email from "Kumar, MBharath" <Bharath.Mora@dell.com>:
# Subject: RE: Dell - Statement - POLYRIX INC. - CA8496521
# Processing message ID: 191bdb0e6a7345e3
# Email from Comptabilite Polyrix <comptabilite@polyrix.com>:
# Subject: Re: Inscription/réautorisation pour Accès Scotia
# Processing message ID: 191bd732acfe16a6
# Processing message ID: 191bd5f83792d351
# Processing message ID: 191bd460fc604fc2
# Processing message ID: 191ba2754bc2449d
# Processing message ID: 191ba1b025bd47c4
# Email from Louis-Andre Deschenes <louis-andre.deschenes@polyrix.com>:
# Subject: Fwd: New invoice / Nouvelle facture
# Processing message ID: 191b98ceddffee9a
# Processing message ID: 191b94b9880235d1
# Processing message ID: 191b94078c359789
# Subject: Re: Dell - Statement - POLYRIX INC. - CA8496521
# Processing message ID: 1916ffd15ef64f5b
# Email from Comptabilite Polyrix <comptabilite@polyrix.com>:
# Subject: Re: ETAT DE COMPTE
# Processing message ID: 1916fde2318e8493
# Email from Jennifer Longo <jenniferlo@aca.ca>:
# Subject: RE: ETAT DE COMPTE
# Processing message ID: 1916fd8f008c0e45
# Email from "Kumar, MBharath" <Bharath.Mora@dell.com>:
# Subject: RE: Dell - Statement - POLYRIX INC. - CA8496521
# Processing message ID: 1916cc44caa11a1c
# Processing message ID: 1916cb54c6facd94
# Processing message ID: 1916cb547430710d
# Processing message ID: 1916c8dec7e85e96
# Email from Comptabilite Polyrix <comptabilite@polyrix.com>:
# Subject: Re: ETAT DE COMPTE
# Processing message ID: 1916c2837fe6ca37
# Email from Comptabilite Polyrix <comptabilite@polyrix.com>:
# Subject: Re: ETAT DE COMPTE
# Processing message ID: 1915c8d107fe3f2c
# Email from Comptabilite Polyrix <comptabilite@polyrix.com>:
# Subject: Re: Dell - Statement - POLYRIX INC. - CA8496521
# Processing message ID: 1915c582c442cb4b
# Email from "Kumar, MBharath" <Bharath.Mora@dell.com>:
# Subject: RE: Dell - Statement - POLYRIX INC. - CA8496521
# Processing message ID: 1915c55b4bfafa81
# Email from Comptabilite Polyrix <comptabilite@polyrix.com>:
# Subject: Re: Dell - Statement - POLYRIX INC. - CA8496521
# Processing message ID: 1915c37372cf30c7
# Email from Comptabilite Polyrix <comptabilite@polyrix.com>:
# Subject: Fwd: Invoice 07.2024
# Error fetching emails: EOF marker not found
# Processing message ID: 1915c33291bd9bc3
# Processing message ID: 1915c320c5e83060
# Processing message ID: 1915bea50d9cd95a
# Email from "Kumar, MBharath" <Bharath.Mora@dell.com>:
# Subject: RE: Dell - Statement - POLYRIX INC. - CA8496521
# Processing message ID: 191587b8337a5acb
# Processing message ID: 19155cebf04f3967
# Processing message ID: 19155cdc49aa5efa
# Processing message ID: 19150e3438e95303
# Email from Comptabilite Polyrix <comptabilite@polyrix.com>:
# Subject: Re: Demande de paiement - POLYRIX au 31/07/2024
# Processing message ID: 1914faa17e03d0a6
# Processing message ID: 1914e440796be51e
# Processing message ID: 1914ac341394f07f
# Processing message ID: 1914a6b04af6bd96
# Email from <bleifuss@ab-kmg.de>:
# Subject: Invoice 07.2024
# Error fetching emails: EOF marker not found
# Processing message ID: 1914a264aa610c14
# Processing message ID: 19148ad3f16051d3
# Processing message ID: 19148ad07c1dce39
# Processing message ID: 191482f22e3230d9
# Email from "Dell | Order Shipped" <ship@order.dell.com>:
# Subject: Your Dell Order Has Been Shipped | Dell Purchase ID: 2009644805623 | Purchase Order: 202406009
# Saved attachment to C:\Users\Isabe\OneDrive\Bureau\attachments\order.dell.com\factures\order.dell.com20240904_CA_ORDERSHIPPED_2009644805623_1008144315_707.OS_.pdf
# Email 191482f22e3230d9 archived under En traitement factures.
# Processing message ID: 1914821ba6a9d0bd
# Email from "Kumar, MBharath" <Bharath.Mora@dell.com>:
# Subject: RE: Dell - Statement - POLYRIX INC. - CA8496521
# Processing message ID: 191480e3e4da6c86
# Email from DCRP Comptabilite <comptabilite@dcrpinnovations.com>:
# Subject: Demande de paiement - POLYRIX au 31/07/2024
# Saved attachment to C:\Users\Isabe\OneDrive\Bureau\attachments\dcrpinnovations.com\factures\dcrpinnovations.com20240904_Etat compte au 31-07-2024 - POLYRIX_.pdf
# Email 191480e3e4da6c86 archived under En traitement factures.
# Processing message ID: 1914634f87b572f0
# Email from Jean-Daniel Deschenes <jean-daniel.deschenes@polyrix.com>:
# Subject: Fwd: Votre compte est en souffrance. Payez maintenant pour rétablir votre compte.
# Processing message ID: 191439ad4da09df1
# Processing message ID: 1913820dddf5efea
# Processing message ID: 19137626dae2528a
# Email from Comptabilite Polyrix <comptabilite@polyrix.com>:
# Subject: Re: Dell - Statement - POLYRIX INC. - CA8496521
# Processing message ID: 19132377a93bed51
# Email from "Kumar, MBharath" <Bharath.Mora@dell.com>:
# Subject: RE: Dell - Statement - POLYRIX INC. - CA8496521
# Processing message ID: 19130255be236f00
# Processing message ID: 1912df30d6f0d206
# Processing message ID: 1912b04178c207d3
# Processing message ID: 191293522317d129
# Email from "Kumar, MBharath" <Bharath.Mora@dell.com>:
# Subject: Dell - Statement - POLYRIX INC. - CA8496521
# Processing message ID: 191274a4b37ed3e5
# Processing message ID: 19126274b21f8e1b
# Processing message ID: 1912469868f0b773
# Email from Jean-Daniel Deschenes <jean-daniel.deschenes@polyrix.com>:
# Subject: Fwd: Votre compte présente un solde en souffrance
# Processing message ID: 191235f9c4bfb853
# Email from DCRP Comptabilite <comptabilite@dcrpinnovations.com>:
# Subject: Correctif de facturation :  F-4630
# Processing message ID: 1912286988373cc0
# Email from Richard Shatilla <richard.shatilla@polyrix.com>:
# Subject: Re: Order confirmation | Your Order no. 202405001 / Our ORD-30009-P2X4Y7 CRM:0171149
# Processing message ID: 19122790bc977379
# Email from David Charland <david.charland@dcrpinnovations.com>:
# Subject: Nouvelle facture F-4699
# Saved attachment to C:\Users\Isabe\OneDrive\Bureau\attachments\dcrpinnovations.com\factures\dcrpinnovations.com20240904_F-4699_.pdf
# Email 19122790bc977379 archived under En traitement factures.
# Processing message ID: 1912049be4903a11
# Email from "Jean-Daniel Deschênes" <jean-daniel.deschenes@polyrix.com>:
# Subject: Fwd: Rappel concernant votre compte #0037061 - Facture #2877306
# FileExistsError: [WinError 183] Impossible de créer un fichier déjà existant: 'C:\\Users\\Isabe\\OneDrive\\Bureau\\attachments\\polyrix.com\\polyrix.com20240904_Sortie_6235106_.pdf' -> 'C:\\Users\\Isabe\\OneDrive\\Bureau\\attachments\\polyrix.com\\factures\\polyrix.com20240904_Sortie_6235106_.pdf' - polyrix.com20240904_Sortie_6235106_.pdf
# Email 1912049be4903a11 archived under En traitement factures.
# Processing message ID: 19117a25660cbe22
# Processing message ID: 19113bf04d185deb
# Email from "Dell | Order Confirmed" <confirmed@order.dell.com>:
# Subject: Your Dell Order Has Been Confirmed | Dell Purchase ID: 2009644805623 | Purchase Order: 202406009
# Saved attachment to C:\Users\Isabe\OneDrive\Bureau\attachments\order.dell.com\factures\order.dell.com20240904_CA_ORDERCONFIRMATION_2009644805623_1008144315_707.OC_.pdf
# Email 19113bf04d185deb archived under En traitement factures.
# Processing message ID: 19113978f7be33d7
# Email from "Dell | Order Received" <received@order.dell.com>:
# Subject: Your Dell Order Has Been Received | Dell Purchase ID: 2009644805623 | Purchase Order: 202406009
# Saved attachment to C:\Users\Isabe\OneDrive\Bureau\attachments\order.dell.com\factures\order.dell.com20240904_CA_OrderAck_bc8a76c6-44fd-41de-8c39-71014271fdfa_.pdf
# Email 19113978f7be33d7 archived under En traitement factures.
# Processing message ID: 1911378da964b1a4
# Email from Louis-Claude Vezina <louis-claude.vezina@polyrix.com>:
# Subject: Fwd: PO 68761 Polyrix
# Processing message ID: 19113256325df477
# Email from Richard Shatilla <richard.shatilla@polyrix.com>:
# Subject: Re: Polyrix 2200000133
# Processing message ID: 19112f7677ff640b
# Email from Raymond Chabot Grant Thornton <rcgt@info.rcgt.com>:
# Subject: Quel est l’impact de l’intelligence artificielle sur notre travail?
# Found 60 messages in the inbox.
# Processing message ID: 19112f750da7e120
# Email from Raymond Chabot Grant Thornton <rcgt@info.rcgt.com>:
# Subject: Quel est l’impact de l’intelligence artificielle sur notre travail?
# Processing message ID: 1910fcd51819d83d
# Email from JOHANNE BELANGER <johanne.belanger@franklinempire.com>:
# Subject: 1087845  - Franklin Empire état de compte
# Saved attachment to C:\Users\Isabe\OneDrive\Bureau\attachments\franklinempire.com\factures\franklinempire.com20240904_Customer_Statement_report_1722543989554_1204les_.pdf
# Email 1910fcd51819d83d archived under En traitement factures.
# Processing message ID: 1910f25db5d95098
# Email from "Guillevin International Co." <noreply-customer_statements@guillevin.com>:
# Subject: Guillevin Monthly Statement / État de compte mensuel
# Saved attachment to C:\Users\Isabe\OneDrive\Bureau\attachments\guillevin.com\factures\guillevin.com20240904_CustState22172-0801241244_.pdf
# Email 1910f25db5d95098 archived under En traitement factures.
# Processing message ID: 1910edda4c3f6b7a
# Processing message ID: 1910ea7d789d4f4c
# Email from "Dell | Order Confirmed" <confirmed@order.dell.com>:
# Subject: Your Dell Order Has Been Confirmed | Dell Purchase ID: 2009644205824 | Purchase Order: 202406009
# Saved attachment to C:\Users\Isabe\OneDrive\Bureau\attachments\order.dell.com\factures\order.dell.com20240904_CA_ORDERCONFIRMATION_2009644205824_1008090118_707.OC_.pdf
# Email 1910ea7d789d4f4c archived under En traitement factures.
# Processing message ID: 1910ea0a1cc2c3af
# Processing message ID: 1910e9d054cecc39
# Email from "Dell | Order Received" <received@order.dell.com>:
# Subject: Your Dell Order Has Been Received | Dell Purchase ID: 2009644205824 | Purchase Order: 202406009
# Saved attachment to C:\Users\Isabe\OneDrive\Bureau\attachments\order.dell.com\factures\order.dell.com20240904_CA_OrderAck_926f252f-d08d-42b0-8e0a-5795bc3eb59a_.pdf
# Email 1910e9d054cecc39 archived under En traitement factures.
# Processing message ID: 1910a6c9a474018f
# Email from Louis-Claude Vezina <louis-claude.vezina@polyrix.com>:
# Subject: Fwd: WDC REMITTNCE INFO. EFFECTIVE DATE 7/31/24
# Processing message ID: 1910a2fbee6d3568
# Email from Kristin-Anne Lapointe <kristinl@aca.ca>:
# Subject: ACA - Invoice SI110708
# Saved attachment to C:\Users\Isabe\OneDrive\Bureau\attachments\aca.ca\factures\aca.ca20240904_Sales Invoice SI110708_.pdf
# Email 1910a2fbee6d3568 archived under En traitement factures.
# Processing message ID: 19108d705b8e35fd
# Processing message ID: 191081dabaacbaf7
# Email from "Guillevin International Co." <noreply-customer_invoices@guillevin.com>:
# Subject: GUILLEVIN INTERNATIONAL CO. - Invoice# 6203349
# Saved attachment to C:\Users\Isabe\OneDrive\Bureau\attachments\guillevin.com\factures\guillevin.com20240904_Inv6203349_.pdf
# Email 191081dabaacbaf7 archived under En traitement factures.
# Processing message ID: 19105e818e682070
# Processing message ID: 191051bf571af50e
# Email from Kristin-Anne Lapointe <kristinl@aca.ca>:
# Subject: ACA - Invoice SI110702
# Saved attachment to C:\Users\Isabe\OneDrive\Bureau\attachments\aca.ca\factures\aca.ca20240904_Sales Invoice SI110702_.pdf
# Email 191051bf571af50e archived under En traitement factures.
# Processing message ID: 191051bc07182422
# Email from Kristin-Anne Lapointe <kristinl@aca.ca>:
# Subject: ACA - Invoice SI110703
# Saved attachment to C:\Users\Isabe\OneDrive\Bureau\attachments\aca.ca\factures\aca.ca20240904_Sales Invoice SI110703_.pdf
# Email 191051bc07182422 archived under En traitement factures.
# Processing message ID: 191042d585aaa545
# Email from Louis-Andre Deschenes <louis-andre.deschenes@polyrix.com>:
# Subject: Fwd: New invoice / Nouvelle facture
# Processing message ID: 191025a3c5f382d2
# Processing message ID: 190ffe4c327e13b6
# Email from Dominic Genest <dominic.genest@polyrix.com>:
# Subject: 6 jours au mois d'aout
# Processing message ID: 190ff1875d9f86f2
# Email from Kristin-Anne Lapointe <kristinl@aca.ca>:
# Subject: ACA - Invoice SI110699
# Saved attachment to C:\Users\Isabe\OneDrive\Bureau\attachments\aca.ca\factures\aca.ca20240904_Sales Invoice SI110699_.pdf
# Email 190ff1875d9f86f2 archived under En traitement factures.
# Processing message ID: 190f3a63ce57b15d
# Processing message ID: 190eefce3db0249c
# Email from Philippe Lambert <philippe.lambert@polyrix.com>:
# Subject: Fwd: 2024-07-26 POLYRIX INC. Référence(s) Holstein Fast Scan Re 10066475, 10066476 R# 016102
# FileExistsError: [WinError 183] Impossible de créer un fichier déjà existant: 'C:\\Users\\Isabe\\OneDrive\\Bureau\\attachments\\polyrix.com\\polyrix.com20240904_10066475_.pdf' -> 'C:\\Users\\Isabe\\OneDrive\\Bureau\\attachments\\polyrix.com\\factures\\polyrix.com20240904_10066475_.pdf' - polyrix.com20240904_10066475_.pdf
